# %%
import pandas as pd

# %%
data = pd.read_csv('ratings.csv')
data.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
data [(data['rating'] == 5.0)]
data.groupby(['movieId'])['userId'].count().sort_values(ascending=False).head()
# Out:
# movieId
# 356     329
# 318     317
# 296     307
# 593     279
# 2571    278
# Name: userId, dtype: int64

# %%
data = pd.read_csv('power.csv')
data.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
data[((data['country'] == 'Latvia') |  (data['country'] == 'Litva') | (data['country'] == 'Estonia')) & ((data['category'] == 4) | (data['category'] == 12) | (data['category'] == 21)) & ((data['year'] <= 2010) | (data['year'] >= 2005))] ['quantity'].count()
# Out:
# 684

# %%
pd.read_html('https://fortrader.org/quotes')
# Out:
# [                               Type    Last   Chg.  Chg.%  Time
#  0  Нефть (BRENT) Курс нефти сегодня  59.110  0.570  0.970   NaN
#  1   Нефть (WTI) Цены на нефть (WTI)  54.760  0.870  1.610   NaN
#  2          Сахар котировки на сахар  12.630  0.000  0.000   NaN
#  3                   Газ Цена на газ   2.205  0.047  2.178   NaN,
#                                      Type          Last      Chg.     Chg.%  \
#  0                      ВТБ Акции ОАО ВТБ       0.03828  +0.00017   0.44608
#  1                 Газпром Акции газпрома     229.66000     +0.34   0.15000
#  2                    Лукоил Акции Лукойл    5164.00000      -4.0  -0.10000
#  3                Роснефть Акции Роснефти     406.45000     +0.70   0.17000
#  4               Сбербанк Акции Сбербанка     218.22000     -1.58  -0.72000
#  5   Сургутнефтегаз Акции Сургутнефтегаза      25.55500    -0.050  -0.19500
#  6              Норникель Акции Норникель   15256.00000      -144  -1.00000
# ...
